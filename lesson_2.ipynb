# %%
DNA = "ATTGCC"

# %%
print("The data type of DNA is ", type(DNA))
# Out:
# The data type of DNA is  <class 'str'>

# %%
num1 = 123

# %%
print("The data type of num1 is ", type(num1))
# Out:
# The data type of num1 is  <class 'int'>

# %%
num2 = 21.19

# %%
print("The data type of num2 is ", type(num2))
# Out:
# The data type of num2 is  <class 'float'>

# %%
num3 = -15

# %%
print("The data type of num3 is ", type(num3))
# Out:
# The data type of num3 is  <class 'int'>

# %%
num4 = 2 + 4j

# %%
print("The data type of num4 is ", type(num4))
# Out:
# The data type of num4 is  <class 'complex'>

# %%
number1 = input("Input the first number ")
number2 = input("Input the second number ")
sum =int(number1) + int(number2)
print(sum)
# Out:
# Input the first number 10
# Input the second number 13
# 23

# %%
#to determine data type
print (type(number1))
# Out:
# <class 'str'>

# %%
#to check if its the expected data type
isinstance(number1, int)
# Out:
# False

# %%
number5 = int(input("Input the first number "))
# Out:
# Input the first number 5

# %%
#to determine data type
print (type(number5))
# Out:
# <class 'int'>

# %%
isinstance(number5, int)
# Out:
# True

# %% [markdown]
# ***Slice***

# %%
print(DNA)
# Out:
# ATTGCC

# %%
print(DNA[0])
# Out:
# A

# %%
print(DNA[0:4])
# Out:
# ATTG
